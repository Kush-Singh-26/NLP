# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
class InputEmbedding(nn.Module):

  def __init__(self, d_model, vocab_size):
    super().__init__()
    self.d_model = d_model
    self.vocab_size = vocab_size
    self.embed = nn.Embedding(num_embeddings=vocab_size, embedding_dim=d_model)

  def forward(self, x):

    return self.embed(x) * math.sqrt(self.d_model)

# %%
class PositionalEncoding(nn.Module):

  def __init__(self, d_model, seq_len, dropout):
    super().__init__()
    self.d_model = d_model
    self.seq_len = seq_len
    self.dropout = nn.Dropout(dropout)
    pe = torch.zeros(seq_len, d_model) # matrix of shape same as embedings
    pos = torch.arange(0, seq_len, dtype=torch.float).unsqueeze(1) # tensor of shape [seq_len, 1] denotes the position of token
    div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model)) # shape of tensor div_term = [d_model // 2]
    pe[:, 0::2] = torch.sin(pos * div_term)
    pe[:, 1::2] = torch.cos(pos * div_term)
    pe = pe.unsqueeze(0) # shape of pe = [1, seq_len, d_model]

    self.register_buffer('pe', pe)

  def forward(self, x):
    x = x + self.pe[:, :x.shape[1], :].requires_grad_(False)  # slicing is done to avoid shape mismatch in variable length sequence
    return self.dropout(x)

# %%
class LayerNorm(nn.Module):

  def __init__(self, d_model, epsilon = 10**-6):

    super().__init__()
    self.epsilon = epsilon
    self.gamma = nn.Parameter(torch.ones(d_model))
    self.beta = nn.Parameter(torch.zeros(d_model))

  # x shape = [batch_size, seq_len, d_model]
  def forward(self, x):

    mean = x.mean(dim=-1, keepdim=True)
    std = x.std(dim=-1, keepdim=True)

    return self.gamma * (x - mean) / (std + self.epsilon) + self.beta # mathematically not exact

# %%
class FeedForward(nn.Module):

  def __init__(self, d_model, d_ff, dropout):

    super().__init__()
    self.layer1 = nn.Linear(d_model, d_ff)
    self.layer2 = nn.Linear(d_ff, d_model)
    self.dropout = nn.Dropout(dropout)

  def forward(self, x):

    return self.layer2(self.dropout(torch.relu(self.layer1(x))))

# %%
class MHA(nn.Module):

  def __init__(self, d_model, h, dropout):

    super().__init__()
    self.d_model = d_model
    self.h = h
    self.dropout = nn.Dropout(dropout)

    self.d_k = d_model // h # d_k = d_v
    self.w_q = nn.Linear(d_model, d_model)
    self.w_k = nn.Linear(d_model, d_model)
    self.w_v = nn.Linear(d_model, d_model)

    self.w_o = nn.Linear(d_model, d_model)

  def forward(self, q, k, v, mask):

    batch_size, seq_len, _ = q.size()

    query = self.w_q(q) # shape of both query and key = [batch_size, seq_len, d_model]
    key = self.w_k(k) # same as query
    value = self.w_v(v) # same as query

    query = query.view(batch_size, -1, self.h, self.d_k) # shape = [batch_size, seq_len, h, d_k]
    query = query.transpose(1, 2) # shape = [batch_size, h, seq_len, d_k]
    key = key.view(batch_size, -1, self.h, self.d_k)
    key = key.transpose(1, 2)
    value = value.view(batch_size, -1, self.h, self.d_k)
    value = value.transpose(1, 2)

    attention_scores = torch.matmul(query, key.transpose(-2, -1)) / math.sqrt(self.d_k) # shape = [batch_size, h, seq_len, seq_len]

    if mask is not None:
      attention_scores = attention_scores.masked_fill_(mask == 0, float('-inf'))

    attention_weights = attention_scores.softmax(dim=-1)

    if self.dropout is not None:
      attention_weights = self.dropout(attention_weights)

    attention_output = attention_weights @  value # shape = [batch_size, h, seq_len, d_k]

    attention_output = attention_output.transpose(1, 2) # shape = [batch_size, seq_len, h, d_k]
    attention_output = attention_output.contiguous() # makes the tensor contiguous in memory for .view as transpose may result in tensor not being stored in a contiguous block of memory
    attention_output = attention_output.view(batch_size, seq_len, self.d_model) # shape = [batch_size, seq_len, d_model]
    attention_output = self.w_o(attention_output) # final projection, same shape
    return attention_output

# %%
class SkipConnection(nn.Module):

  def __init__(self, dropout, d_model):

    super().__init__()
    self.dropout = nn.Dropout(dropout)
    self.norm = LayerNorm(d_model)

  def forward(self, x, sublayer):

    return x + self.dropout(sublayer(self.norm(x))) # pre-norm

# %%
class EncoderBlock(nn.Module):

  def __init__(self, attention, ffn, dropout, d_model):

    super().__init__()
    self.attention = attention
    self.ffn = ffn
    self.residual = nn.ModuleList([SkipConnection(dropout, d_model) for _ in range(2)])

  # src_mask is used to mask out padding tokens in encoder
  def forward(self, x, src_mask):
    x = self.residual[0](x, lambda y: self.attention(y, y, y, src_mask))
    x = self.residual[1](x, self.ffn)
    return x

# %%
class Encoder(nn.Module):

  def __init__(self, d_model, layers):

    super().__init__()
    self.layers = layers
    self.norm = LayerNorm(d_model)

  def forward(self, x, mask):

    for layer in self.layers:
      x = layer(x, mask)
    return self.norm(x)

# %%
class DecoderBlock(nn.Module):

  def __init__(self, self_attention, cross_attention, ffn, dropout, d_model):

    super().__init__()
    self.self_attention = self_attention
    self.cross_attention = cross_attention
    self.ffn = ffn
    self.residual = nn.ModuleList([SkipConnection(dropout, d_model) for _ in range(3)])

  def forward(self, x, encoder_output, src_mask, trg_mask):

    x = self.residual[0](x, lambda y: self.self_attention(y, y, y, trg_mask))
    x = self.residual[1](x, lambda y: self.cross_attention(y, encoder_output, encoder_output, src_mask))
    x = self.residual[2](x, self.ffn)

    return x

# %%
class Decoder(nn.Module):

  def __init__(self, d_model, layers):

    super().__init__()
    self.layers = layers
    self.norm = LayerNorm(d_model)

  def forward(self, x, encoder_output, src_mask, trg_mask):

    for layer in self.layers:
      x = layer(x, encoder_output, src_mask, trg_mask)

    return self.norm(x)

# %%
class Output(nn.Module):

  def __init__(self, d_model, vocab_size):

    super().__init__()
    self.proj = nn.Linear(d_model, vocab_size)

  def forward(self, x):

    return self.proj(x)

# %%
class Transformer(nn.Module):

  def __init__(self, encoder, decoder, src_embed, trg_embed, src_pos, trg_pos, output):

    super().__init__()
    self.encoder = encoder
    self.decoder = decoder
    self.src_embed = src_embed
    self.trg_embed = trg_embed
    self.src_pos = src_pos
    self.trg_pos = trg_pos
    self.output_layer = output

  def encode(self, src, src_mask):

    src = self.src_embed(src)
    src = self.src_pos(src)
    return self.encoder(src, src_mask)

  def decode(self, encoder_output, src_mask, trg, trg_mask):

    trg = self.trg_embed(trg)
    trg = self.trg_pos(trg)
    return self.decoder(trg, encoder_output, src_mask, trg_mask)

  def project(self, x):

    return self.output_layer(x)

  def forward(self, src, trg):
        # Create masks for source and target
        # Target mask is a combination of padding mask and subsequent mask
        src_mask = (src != PAD_token).unsqueeze(1).unsqueeze(2) # (batch, 1, 1, src_len)
        trg_mask = (trg != PAD_token).unsqueeze(1).unsqueeze(2) # (batch, 1, 1, trg_len)

        seq_length = trg.size(1)
        subsequent_mask = torch.tril(torch.ones(1, seq_length, seq_length)).to(device) # (1, trg_len, trg_len)
        trg_mask = trg_mask & (subsequent_mask==1)

        encoder_output = self.encode(src, src_mask)
        decoder_output = self.decode(encoder_output, src_mask, trg, trg_mask)
        return self.project(decoder_output)

# %%
def BuildTransformer(src_vocab_size, trg_vocab_size, src_seq_len, trg_seq_len, d_model=512, N=6, h=8, dropout=0.1, d_ff=2048):

  src_embed = InputEmbedding(d_model, src_vocab_size)
  trg_embed = InputEmbedding(d_model, trg_vocab_size)

  src_pos = PositionalEncoding(d_model, src_seq_len, dropout)
  trg_pos = PositionalEncoding(d_model, trg_seq_len, dropout)

  encoder_blocks = []
  for _ in range(N):
    encoder_self_attention = MHA(d_model, h, dropout)
    ffn = FeedForward(d_model, d_ff, dropout)
    encoder_block = EncoderBlock(encoder_self_attention, ffn, dropout, d_model)
    encoder_blocks.append(encoder_block)

  decoder_blocks = []
  for _ in range(N):
    decoder_mask_attention = MHA(d_model, h, dropout)
    cross_attention = MHA(d_model, h, dropout)
    ffn = FeedForward(d_model, d_ff, dropout)
    decoder_block = DecoderBlock(decoder_mask_attention, cross_attention, ffn, dropout, d_model)
    decoder_blocks.append(decoder_block)

  encoder = Encoder(d_model, nn.ModuleList(encoder_blocks))
  decoder = Decoder(d_model, nn.ModuleList(decoder_blocks))

  projection = Output(d_model, trg_vocab_size)

  transformer = Transformer(encoder, decoder, src_embed, trg_embed, src_pos, trg_pos, projection)

  for p in transformer.parameters():
    if p.dim() > 1:
      nn.init.xavier_uniform_(p)

  return transformer

# %%
from tqdm import tqdm
import random

# %%
from tokenizers import Tokenizer

tokenizer = Tokenizer.from_file("/content/drive/MyDrive/hindi-english_bpe_tokenizer.json")

# %%
! pip install -U datasets huggingface_hub fsspec

# %%
from datasets import load_dataset

MAX_LEN = 512

def filter_long_example(example):
  return len(example['translation']['en']) < MAX_LEN and \
         len(example['translation']['hi']) < MAX_LEN

ds = load_dataset("cfilt/iitb-english-hindi")

ds = ds.filter(filter_long_example)

# %%
from torch.utils.data import Dataset, DataLoader
from torch.nn.utils.rnn import pad_sequence

# Add special tokens
if tokenizer.token_to_id("[SOS]") is None:
    tokenizer.add_special_tokens(['[SOS]'])
if tokenizer.token_to_id("[EOS]") is None:
    tokenizer.add_special_tokens(['[EOS]'])

# Define special token IDs
SOS_token = tokenizer.token_to_id('[SOS]')
EOS_token = tokenizer.token_to_id('[EOS]')
PAD_token = tokenizer.token_to_id('[PAD]')

class TranslationDataset(Dataset):
    def __init__(self, dataset, tokenizer, src_lang="en", tgt_lang="hi"):
        self.dataset = dataset
        self.tokenizer = tokenizer
        self.src_lang = src_lang
        self.tgt_lang = tgt_lang

    def __len__(self):
        return len(self.dataset)

    def __getitem__(self, idx):
        src_text = self.dataset[idx]["translation"][self.src_lang]
        tgt_text = self.dataset[idx]["translation"][self.tgt_lang]

        # Tokenize and add special tokens
        src_ids = [SOS_token] + self.tokenizer.encode(src_text).ids + [EOS_token]
        tgt_ids = [SOS_token] + self.tokenizer.encode(tgt_text).ids + [EOS_token]

        return torch.tensor(src_ids), torch.tensor(tgt_ids)

# Create instances of the dataset for training and validation
train_dataset = TranslationDataset(ds["train"], tokenizer)
val_dataset = TranslationDataset(ds["validation"], tokenizer)

def collate_fn(batch):
    src_batch, tgt_batch = [], []
    for src_sample, tgt_sample in batch:
        src_batch.append(src_sample)
        tgt_batch.append(tgt_sample)

    # Pad sequences to the length of the longest sequence in the batch
    src_batch = pad_sequence(src_batch, padding_value=PAD_token, batch_first=True)
    tgt_batch = pad_sequence(tgt_batch, padding_value=PAD_token, batch_first=True)

    return src_batch, tgt_batch

# Create the DataLoaders
batch_size = 32
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, collate_fn=collate_fn)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, collate_fn=collate_fn)

# %%
config = {
    "epochs": 15,
    "batch_size": 16,
    "d_model": 512,
    "num_layers": 6,
    "num_heads": 8,
    "d_ff": 2048,
    "dropout": 0.1,
    "learning_rate": 0.0001,
    "max_seq_len": 512,
    "accumulation_steps": 4,
    "logging_interval": 200
}

# %%
src_vocab_size = tokenizer.get_vocab_size()
trg_vocab_size = tokenizer.get_vocab_size()

src_seq_len = 512
trg_seq_len = 512
d_model = 256
num_heads = 8
num_layers = 6
d_ff = 2048
dropout = 0.1

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
PAD_token = tokenizer.token_to_id('[PAD]')

# %%
model = BuildTransformer(src_vocab_size,
                         trg_vocab_size,
                         src_seq_len,
                         trg_seq_len,
                         d_model,
                         num_layers,
                         num_heads,
                         dropout,
                         d_ff).to(device)

# %%
criterion = nn.CrossEntropyLoss(ignore_index=PAD_token)
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001, betas=(0.9, 0.98), eps=1e-9)

# %%
from torch.cuda.amp import GradScaler, autocast
import time

# %%
scaler = GradScaler()

def train_epoch(model, dataloader, optimizer, criterion, device, config, epoch_num):

    model.train()

    epoch_start_time = time.time()
    total_epoch_loss = 0.0

    chunk_start_time = time.time()
    chunk_losses = []
    chunk_tokens = 0

    num_batches = len(dataloader)

    optimizer.zero_grad()

    for i, (src_batch, tgt_batch) in enumerate(dataloader):
        src_batch = src_batch.to(device)
        tgt_batch = tgt_batch.to(device)

        tgt_input = tgt_batch[:, :-1]
        tgt_out = tgt_batch[:, 1:]

        with torch.cuda.amp.autocast():
            output = model(src_batch, tgt_input)
            output_flat = output.contiguous().view(-1, output.shape[-1])
            tgt_out_flat = tgt_out.contiguous().view(-1)
            loss = criterion(output_flat, tgt_out_flat)
            loss = loss / config['accumulation_steps']

        scaler.scale(loss).backward()

        if (i + 1) % config['accumulation_steps'] == 0:
            scaler.unscale_(optimizer)
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            scaler.step(optimizer)
            scaler.update()
            optimizer.zero_grad()

        current_loss = loss.item() * config['accumulation_steps']
        chunk_losses.append(current_loss)
        total_epoch_loss += current_loss

        num_target_tokens = (tgt_batch != PAD_token).sum().item()
        chunk_tokens += num_target_tokens

        if (i + 1) % config['logging_interval'] == 0:
            avg_chunk_loss = sum(chunk_losses) / len(chunk_losses)
            chunk_ppl = math.exp(avg_chunk_loss)

            time_for_chunk = time.time() - chunk_start_time
            bps = chunk_tokens / time_for_chunk

            print(f"  Batch {i+1:5d}/{num_batches:5d}   | Avg Loss (last {config['logging_interval']}): {avg_chunk_loss:.4f} | "
                  f"PPL: {chunk_ppl:7.2f} | Tokens/Sec: {bps:7.2f}")

            chunk_start_time = time.time()
            chunk_losses = []
            chunk_tokens = 0

    epoch_duration = time.time() - epoch_start_time
    avg_epoch_loss = total_epoch_loss / num_batches

    return avg_epoch_loss, epoch_duration
# Out:
# /tmp/ipython-input-26-392631358.py:2: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler()

# %%
import math
from tqdm import tqdm
import torch

def evaluate(model, dataloader, criterion, device):

    model.eval()
    total_loss = 0

    with torch.no_grad():
        data_iterator = tqdm(dataloader, desc="Validating")
        for src_batch, tgt_batch in data_iterator:
            src_batch = src_batch.to(device)
            tgt_batch = tgt_batch.to(device)

            tgt_input = tgt_batch[:, :-1]
            tgt_out = tgt_batch[:, 1:]

            output = model(src_batch, tgt_input)
            output_flat = output.contiguous().view(-1, output.shape[-1])
            tgt_out_flat = tgt_out.contiguous().view(-1)

            loss = criterion(output_flat, tgt_out_flat)
            total_loss += loss.item()

    return total_loss / len(dataloader)

# %%
check_point_path = '/content/drive/MyDrive/transformer_new_checkpoint.pth'

# %%
checkpoint = torch.load(check_point_path, map_location=device)

# %%
model.load_state_dict(checkpoint['model_state_dict'])
optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
scaler.load_state_dict(checkpoint['scaler_state_dict'])

# %%
start_epoch = checkpoint['epoch'] + 1

# %%
print(start_epoch)
# Out:
# 3

# %%
if 'loss' in checkpoint:
        best_val_loss = checkpoint['loss']

# %%
print(best_val_loss)
print('hello')
# Out:
# 3.290837568395278
# hello

# %%
model_save_path = '/content/drive/MyDrive/transformer_new_checkpoint.pth'

# %%
for epoch in range(start_epoch ,config['epochs']):
    print(f"--- Epoch {epoch+1:02d}/{config['epochs']:02d} ---")

    train_loss, train_duration = train_epoch(
        model, train_dataloader, optimizer, criterion, device, config, epoch + 1
    )

    val_loss = evaluate(
        model, val_dataloader, criterion, device
    )

    train_ppl = math.exp(train_loss)
    val_ppl = math.exp(val_loss)

    mins, secs = divmod(train_duration, 60)

    print(f"End of Epoch: {epoch+1:02d} | Time: {int(mins)}m {int(secs)}s")
    print(f"\tEpoch Train Loss: {train_loss:.3f} | Epoch Train PPL: {train_ppl:7.3f}")
    print(f"\tEpoch Val. Loss: {val_loss:.3f} |  Epoch Val. PPL: {val_ppl:7.3f}")
    print("-" * 70)
    torch.save({
        'epoch': epoch,
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
        'scaler_state_dict': scaler.state_dict(),
        'loss': val_loss,
    }, model_save_path)

print("Training finished.")
# Out:
# --- Epoch 04/15 ---
# /tmp/ipython-input-26-392631358.py:26: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
#   Batch   200/51579   | Avg Loss (last 200): 2.7100 | PPL:   15.03 | Tokens/Sec: 4539.65
#   Batch   400/51579   | Avg Loss (last 200): 2.6926 | PPL:   14.77 | Tokens/Sec: 5987.87
#   Batch   600/51579   | Avg Loss (last 200): 2.6985 | PPL:   14.86 | Tokens/Sec: 6241.86
#   Batch   800/51579   | Avg Loss (last 200): 2.7161 | PPL:   15.12 | Tokens/Sec: 5735.05
#   Batch  1000/51579   | Avg Loss (last 200): 2.7161 | PPL:   15.12 | Tokens/Sec: 5964.28
#   Batch  1200/51579   | Avg Loss (last 200): 2.6852 | PPL:   14.66 | Tokens/Sec: 6110.24
#   Batch  1400/51579   | Avg Loss (last 200): 2.7313 | PPL:   15.35 | Tokens/Sec: 5864.94
#   Batch  1600/51579   | Avg Loss (last 200): 2.7249 | PPL:   15.25 | Tokens/Sec: 6210.40
#   Batch  1800/51579   | Avg Loss (last 200): 2.6749 | PPL:   14.51 | Tokens/Sec: 5964.74
#   Batch  2000/51579   | Avg Loss (last 200): 2.7281 | PPL:   15.30 | Tokens/Sec: 6018.89
#   Batch  2200/51579   | Avg Loss (last 200): 2.7390 | PPL:   15.47 | Tokens/Sec: 6078.49
#   Batch  2400/51579   | Avg Loss (last 200): 2.6924 | PPL:   14.77 | Tokens/Sec: 5870.44
#   Batch  2600/51579   | Avg Loss (last 200): 2.6788 | PPL:   14.57 | Tokens/Sec: 6115.17
#   Batch  2800/51579   | Avg Loss (last 200): 2.6957 | PPL:   14.82 | Tokens/Sec: 5879.52
#   Batch  3000/51579   | Avg Loss (last 200): 2.7054 | PPL:   14.96 | Tokens/Sec: 5934.34
#   Batch  3200/51579   | Avg Loss (last 200): 2.6988 | PPL:   14.86 | Tokens/Sec: 6106.19
#   Batch  3400/51579   | Avg Loss (last 200): 2.7130 | PPL:   15.07 | Tokens/Sec: 5865.54
#   Batch  3600/51579   | Avg Loss (last 200): 2.7028 | PPL:   14.92 | Tokens/Sec: 6065.58
#   Batch  3800/51579   | Avg Loss (last 200): 2.6797 | PPL:   14.58 | Tokens/Sec: 5993.56
#   Batch  4000/51579   | Avg Loss (last 200): 2.7081 | PPL:   15.00 | Tokens/Sec: 5980.79
#   Batch  4200/51579   | Avg Loss (last 200): 2.6811 | PPL:   14.60 | Tokens/Sec: 6079.59
#   Batch  4400/51579   | Avg Loss (last 200): 2.6873 | PPL:   14.69 | Tokens/Sec: 6111.31
#   Batch  4600/51579   | Avg Loss (last 200): 2.6965 | PPL:   14.83 | Tokens/Sec: 6104.27
#   Batch  4800/51579   | Avg Loss (last 200): 2.6771 | PPL:   14.54 | Tokens/Sec: 5857.06
#   Batch  5000/51579   | Avg Loss (last 200): 2.7111 | PPL:   15.05 | Tokens/Sec: 6046.86
#   Batch  5200/51579   | Avg Loss (last 200): 2.7120 | PPL:   15.06 | Tokens/Sec: 5842.00
#   Batch  5400/51579   | Avg Loss (last 200): 2.7084 | PPL:   15.01 | Tokens/Sec: 6125.33
#   Batch  5600/51579   | Avg Loss (last 200): 2.7015 | PPL:   14.90 | Tokens/Sec: 5946.91
#   Batch  5800/51579   | Avg Loss (last 200): 2.7318 | PPL:   15.36 | Tokens/Sec: 5908.00
#   Batch  6000/51579   | Avg Loss (last 200): 2.7297 | PPL:   15.33 | Tokens/Sec: 5906.63
#   Batch  6200/51579   | Avg Loss (last 200): 2.7307 | PPL:   15.34 | Tokens/Sec: 5715.66
#   Batch  6400/51579   | Avg Loss (last 200): 2.7093 | PPL:   15.02 | Tokens/Sec: 5953.34
#   Batch  6600/51579   | Avg Loss (last 200): 2.6837 | PPL:   14.64 | Tokens/Sec: 5964.89
#   Batch  6800/51579   | Avg Loss (last 200): 2.6853 | PPL:   14.66 | Tokens/Sec: 5857.73
#   Batch  7000/51579   | Avg Loss (last 200): 2.7050 | PPL:   14.95 | Tokens/Sec: 6030.51
#   Batch  7200/51579   | Avg Loss (last 200): 2.7088 | PPL:   15.01 | Tokens/Sec: 6020.58
#   Batch  7400/51579   | Avg Loss (last 200): 2.6942 | PPL:   14.79 | Tokens/Sec: 5940.71
#   Batch  7600/51579   | Avg Loss (last 200): 2.7222 | PPL:   15.21 | Tokens/Sec: 5961.03
#   Batch  7800/51579   | Avg Loss (last 200): 2.6915 | PPL:   14.75 | Tokens/Sec: 5710.51
#   Batch  8000/51579   | Avg Loss (last 200): 2.6853 | PPL:   14.66 | Tokens/Sec: 6013.14
#   Batch  8200/51579   | Avg Loss (last 200): 2.6915 | PPL:   14.75 | Tokens/Sec: 5593.92
#   Batch  8400/51579   | Avg Loss (last 200): 2.6921 | PPL:   14.76 | Tokens/Sec: 5807.63
#   Batch  8600/51579   | Avg Loss (last 200): 2.7134 | PPL:   15.08 | Tokens/Sec: 5819.83
#   Batch  8800/51579   | Avg Loss (last 200): 2.6917 | PPL:   14.76 | Tokens/Sec: 5755.08
#   Batch  9000/51579   | Avg Loss (last 200): 2.6796 | PPL:   14.58 | Tokens/Sec: 5776.33
#   Batch  9200/51579   | Avg Loss (last 200): 2.6826 | PPL:   14.62 | Tokens/Sec: 5819.94
#   Batch  9400/51579   | Avg Loss (last 200): 2.7053 | PPL:   14.96 | Tokens/Sec: 5785.63
#   Batch  9600/51579   | Avg Loss (last 200): 2.6649 | PPL:   14.37 | Tokens/Sec: 5685.67
#   Batch  9800/51579   | Avg Loss (last 200): 2.6648 | PPL:   14.36 | Tokens/Sec: 5676.86
#   Batch 10000/51579   | Avg Loss (last 200): 2.7098 | PPL:   15.03 | Tokens/Sec: 5702.67
#   Batch 10200/51579   | Avg Loss (last 200): 2.6796 | PPL:   14.58 | Tokens/Sec: 5864.40
#   Batch 10400/51579   | Avg Loss (last 200): 2.6727 | PPL:   14.48 | Tokens/Sec: 5759.14
#   Batch 10600/51579   | Avg Loss (last 200): 2.7055 | PPL:   14.96 | Tokens/Sec: 5687.54
#   Batch 10800/51579   | Avg Loss (last 200): 2.6784 | PPL:   14.56 | Tokens/Sec: 5892.47
#   Batch 11000/51579   | Avg Loss (last 200): 2.6569 | PPL:   14.25 | Tokens/Sec: 5815.50
#   Batch 11200/51579   | Avg Loss (last 200): 2.7302 | PPL:   15.34 | Tokens/Sec: 6034.80
#   Batch 11400/51579   | Avg Loss (last 200): 2.7003 | PPL:   14.88 | Tokens/Sec: 6029.71
#   Batch 11600/51579   | Avg Loss (last 200): 2.6899 | PPL:   14.73 | Tokens/Sec: 5894.46
#   Batch 11800/51579   | Avg Loss (last 200): 2.7089 | PPL:   15.01 | Tokens/Sec: 6187.01
#   Batch 12000/51579   | Avg Loss (last 200): 2.6922 | PPL:   14.76 | Tokens/Sec: 5860.00
#   Batch 12200/51579   | Avg Loss (last 200): 2.6805 | PPL:   14.59 | Tokens/Sec: 6048.16
#   Batch 12400/51579   | Avg Loss (last 200): 2.6789 | PPL:   14.57 | Tokens/Sec: 5820.54
#   Batch 12600/51579   | Avg Loss (last 200): 2.6678 | PPL:   14.41 | Tokens/Sec: 5758.43
#   Batch 12800/51579   | Avg Loss (last 200): 2.6876 | PPL:   14.70 | Tokens/Sec: 6014.40
#   Batch 13000/51579   | Avg Loss (last 200): 2.6914 | PPL:   14.75 | Tokens/Sec: 5808.05
#   Batch 13200/51579   | Avg Loss (last 200): 2.6875 | PPL:   14.70 | Tokens/Sec: 6010.96
#   Batch 13400/51579   | Avg Loss (last 200): 2.6663 | PPL:   14.39 | Tokens/Sec: 5946.05
#   Batch 13600/51579   | Avg Loss (last 200): 2.6825 | PPL:   14.62 | Tokens/Sec: 5902.43
#   Batch 13800/51579   | Avg Loss (last 200): 2.6755 | PPL:   14.52 | Tokens/Sec: 6036.73
#   Batch 14000/51579   | Avg Loss (last 200): 2.6694 | PPL:   14.43 | Tokens/Sec: 5818.13
#   Batch 14200/51579   | Avg Loss (last 200): 2.6900 | PPL:   14.73 | Tokens/Sec: 5942.74
#   Batch 14400/51579   | Avg Loss (last 200): 2.6679 | PPL:   14.41 | Tokens/Sec: 6105.23
#   Batch 14600/51579   | Avg Loss (last 200): 2.6580 | PPL:   14.27 | Tokens/Sec: 5929.23
#   Batch 14800/51579   | Avg Loss (last 200): 2.6852 | PPL:   14.66 | Tokens/Sec: 6096.30
#   Batch 15000/51579   | Avg Loss (last 200): 2.6409 | PPL:   14.03 | Tokens/Sec: 6024.90
#   Batch 15200/51579   | Avg Loss (last 200): 2.6940 | PPL:   14.79 | Tokens/Sec: 6105.36
#   Batch 15400/51579   | Avg Loss (last 200): 2.7016 | PPL:   14.90 | Tokens/Sec: 5796.86
#   Batch 15600/51579   | Avg Loss (last 200): 2.6483 | PPL:   14.13 | Tokens/Sec: 5839.82
#   Batch 15800/51579   | Avg Loss (last 200): 2.6858 | PPL:   14.67 | Tokens/Sec: 5989.06
#   Batch 16000/51579   | Avg Loss (last 200): 2.6737 | PPL:   14.49 | Tokens/Sec: 5888.13
#   Batch 16200/51579   | Avg Loss (last 200): 2.6552 | PPL:   14.23 | Tokens/Sec: 6064.77
#   Batch 16400/51579   | Avg Loss (last 200): 2.6604 | PPL:   14.30 | Tokens/Sec: 5871.81
#   Batch 16600/51579   | Avg Loss (last 200): 2.6755 | PPL:   14.52 | Tokens/Sec: 5886.94
#   Batch 16800/51579   | Avg Loss (last 200): 2.6850 | PPL:   14.66 | Tokens/Sec: 5906.01
#   Batch 17000/51579   | Avg Loss (last 200): 2.6659 | PPL:   14.38 | Tokens/Sec: 5844.18
#   Batch 17200/51579   | Avg Loss (last 200): 2.6975 | PPL:   14.84 | Tokens/Sec: 5950.61
#   Batch 17400/51579   | Avg Loss (last 200): 2.7061 | PPL:   14.97 | Tokens/Sec: 5802.24
#   Batch 17600/51579   | Avg Loss (last 200): 2.6835 | PPL:   14.64 | Tokens/Sec: 5889.29
#   Batch 17800/51579   | Avg Loss (last 200): 2.6593 | PPL:   14.29 | Tokens/Sec: 6046.19
#   Batch 18000/51579   | Avg Loss (last 200): 2.6583 | PPL:   14.27 | Tokens/Sec: 5891.61
#   Batch 18200/51579   | Avg Loss (last 200): 2.6660 | PPL:   14.38 | Tokens/Sec: 5913.39
#   Batch 18400/51579   | Avg Loss (last 200): 2.6658 | PPL:   14.38 | Tokens/Sec: 5963.93
#   Batch 18600/51579   | Avg Loss (last 200): 2.6766 | PPL:   14.54 | Tokens/Sec: 5891.35
#   Batch 18800/51579   | Avg Loss (last 200): 2.6315 | PPL:   13.90 | Tokens/Sec: 6234.30
#   Batch 19000/51579   | Avg Loss (last 200): 2.6745 | PPL:   14.51 | Tokens/Sec: 5902.07
#   Batch 19200/51579   | Avg Loss (last 200): 2.6634 | PPL:   14.35 | Tokens/Sec: 6185.78
#   Batch 19400/51579   | Avg Loss (last 200): 2.6638 | PPL:   14.35 | Tokens/Sec: 6004.86
#   Batch 19600/51579   | Avg Loss (last 200): 2.6175 | PPL:   13.70 | Tokens/Sec: 5875.24
#   Batch 19800/51579   | Avg Loss (last 200): 2.6752 | PPL:   14.52 | Tokens/Sec: 6036.36
#   Batch 20000/51579   | Avg Loss (last 200): 2.6706 | PPL:   14.45 | Tokens/Sec: 5856.82
#   Batch 20200/51579   | Avg Loss (last 200): 2.6544 | PPL:   14.22 | Tokens/Sec: 6173.54
#   Batch 20400/51579   | Avg Loss (last 200): 2.6742 | PPL:   14.50 | Tokens/Sec: 5797.19
#   Batch 20600/51579   | Avg Loss (last 200): 2.6944 | PPL:   14.80 | Tokens/Sec: 5856.55
#   Batch 20800/51579   | Avg Loss (last 200): 2.7037 | PPL:   14.94 | Tokens/Sec: 6017.75
#   Batch 21000/51579   | Avg Loss (last 200): 2.6467 | PPL:   14.11 | Tokens/Sec: 5838.15
#   Batch 21200/51579   | Avg Loss (last 200): 2.6799 | PPL:   14.58 | Tokens/Sec: 6044.22
#   Batch 21400/51579   | Avg Loss (last 200): 2.6699 | PPL:   14.44 | Tokens/Sec: 5813.19
#   Batch 21600/51579   | Avg Loss (last 200): 2.6691 | PPL:   14.43 | Tokens/Sec: 5678.66
#   Batch 21800/51579   | Avg Loss (last 200): 2.6642 | PPL:   14.36 | Tokens/Sec: 5916.06
#   Batch 22000/51579   | Avg Loss (last 200): 2.6525 | PPL:   14.19 | Tokens/Sec: 5707.67
#   Batch 22200/51579   | Avg Loss (last 200): 2.6505 | PPL:   14.16 | Tokens/Sec: 5695.44
#   Batch 22400/51579   | Avg Loss (last 200): 2.6604 | PPL:   14.30 | Tokens/Sec: 5782.45
#   Batch 22600/51579   | Avg Loss (last 200): 2.6727 | PPL:   14.48 | Tokens/Sec: 5671.19
#   Batch 22800/51579   | Avg Loss (last 200): 2.6587 | PPL:   14.28 | Tokens/Sec: 5765.69
#   Batch 23000/51579   | Avg Loss (last 200): 2.6492 | PPL:   14.14 | Tokens/Sec: 5797.50
#   Batch 23200/51579   | Avg Loss (last 200): 2.6593 | PPL:   14.29 | Tokens/Sec: 5632.21
#   Batch 23400/51579   | Avg Loss (last 200): 2.6593 | PPL:   14.29 | Tokens/Sec: 5781.77
#   Batch 23600/51579   | Avg Loss (last 200): 2.6555 | PPL:   14.23 | Tokens/Sec: 5303.67
#   Batch 23800/51579   | Avg Loss (last 200): 2.6550 | PPL:   14.23 | Tokens/Sec: 5697.10
#   Batch 24000/51579   | Avg Loss (last 200): 2.6542 | PPL:   14.21 | Tokens/Sec: 5681.71
#   Batch 24200/51579   | Avg Loss (last 200): 2.6579 | PPL:   14.27 | Tokens/Sec: 5813.26
#   Batch 24400/51579   | Avg Loss (last 200): 2.6399 | PPL:   14.01 | Tokens/Sec: 6033.09
#   Batch 24600/51579   | Avg Loss (last 200): 2.6524 | PPL:   14.19 | Tokens/Sec: 6215.91
#   Batch 24800/51579   | Avg Loss (last 200): 2.6415 | PPL:   14.03 | Tokens/Sec: 5966.48
#   Batch 25000/51579   | Avg Loss (last 200): 2.6548 | PPL:   14.22 | Tokens/Sec: 6044.09
#   Batch 25200/51579   | Avg Loss (last 200): 2.6279 | PPL:   13.84 | Tokens/Sec: 5899.35
#   Batch 25400/51579   | Avg Loss (last 200): 2.6257 | PPL:   13.81 | Tokens/Sec: 5975.94
#   Batch 25600/51579   | Avg Loss (last 200): 2.6421 | PPL:   14.04 | Tokens/Sec: 6033.10
#   Batch 25800/51579   | Avg Loss (last 200): 2.6498 | PPL:   14.15 | Tokens/Sec: 5991.31
#   Batch 26000/51579   | Avg Loss (last 200): 2.6531 | PPL:   14.20 | Tokens/Sec: 6055.09
#   Batch 26200/51579   | Avg Loss (last 200): 2.6053 | PPL:   13.53 | Tokens/Sec: 5892.51
#   Batch 26400/51579   | Avg Loss (last 200): 2.6477 | PPL:   14.12 | Tokens/Sec: 5859.40
#   Batch 26600/51579   | Avg Loss (last 200): 2.6422 | PPL:   14.04 | Tokens/Sec: 6024.74
#   Batch 26800/51579   | Avg Loss (last 200): 2.6651 | PPL:   14.37 | Tokens/Sec: 5960.93
#   Batch 27000/51579   | Avg Loss (last 200): 2.6261 | PPL:   13.82 | Tokens/Sec: 6089.03
#   Batch 27200/51579   | Avg Loss (last 200): 2.6486 | PPL:   14.13 | Tokens/Sec: 6023.12
#   Batch 27400/51579   | Avg Loss (last 200): 2.6565 | PPL:   14.25 | Tokens/Sec: 5966.57
#   Batch 27600/51579   | Avg Loss (last 200): 2.6174 | PPL:   13.70 | Tokens/Sec: 6021.40
#   Batch 27800/51579   | Avg Loss (last 200): 2.6426 | PPL:   14.05 | Tokens/Sec: 5899.00
#   Batch 28000/51579   | Avg Loss (last 200): 2.6040 | PPL:   13.52 | Tokens/Sec: 6124.80
#   Batch 28200/51579   | Avg Loss (last 200): 2.6373 | PPL:   13.98 | Tokens/Sec: 5931.01
#   Batch 28400/51579   | Avg Loss (last 200): 2.6388 | PPL:   14.00 | Tokens/Sec: 6223.02
#   Batch 28600/51579   | Avg Loss (last 200): 2.6403 | PPL:   14.02 | Tokens/Sec: 5915.80
#   Batch 28800/51579   | Avg Loss (last 200): 2.6471 | PPL:   14.11 | Tokens/Sec: 6046.34
#   Batch 29000/51579   | Avg Loss (last 200): 2.6495 | PPL:   14.15 | Tokens/Sec: 5991.66
#   Batch 29200/51579   | Avg Loss (last 200): 2.6152 | PPL:   13.67 | Tokens/Sec: 5967.23
#   Batch 29400/51579   | Avg Loss (last 200): 2.6233 | PPL:   13.78 | Tokens/Sec: 6153.15
#   Batch 29600/51579   | Avg Loss (last 200): 2.6376 | PPL:   13.98 | Tokens/Sec: 6006.48
#   Batch 29800/51579   | Avg Loss (last 200): 2.5988 | PPL:   13.45 | Tokens/Sec: 6213.95
#   Batch 30000/51579   | Avg Loss (last 200): 2.6060 | PPL:   13.55 | Tokens/Sec: 6102.17
#   Batch 30200/51579   | Avg Loss (last 200): 2.6387 | PPL:   14.00 | Tokens/Sec: 6156.94
#   Batch 30400/51579   | Avg Loss (last 200): 2.6628 | PPL:   14.34 | Tokens/Sec: 6112.47
#   Batch 30600/51579   | Avg Loss (last 200): 2.6416 | PPL:   14.03 | Tokens/Sec: 6035.29
#   Batch 30800/51579   | Avg Loss (last 200): 2.6509 | PPL:   14.17 | Tokens/Sec: 6201.67
#   Batch 31000/51579   | Avg Loss (last 200): 2.6175 | PPL:   13.70 | Tokens/Sec: 5997.46
#   Batch 31200/51579   | Avg Loss (last 200): 2.6320 | PPL:   13.90 | Tokens/Sec: 6160.47
#   Batch 31400/51579   | Avg Loss (last 200): 2.6372 | PPL:   13.97 | Tokens/Sec: 6016.07
#   Batch 31600/51579   | Avg Loss (last 200): 2.6352 | PPL:   13.95 | Tokens/Sec: 5918.71
#   Batch 31800/51579   | Avg Loss (last 200): 2.6115 | PPL:   13.62 | Tokens/Sec: 6017.92
#   Batch 32000/51579   | Avg Loss (last 200): 2.6245 | PPL:   13.80 | Tokens/Sec: 5959.15
#   Batch 32200/51579   | Avg Loss (last 200): 2.6400 | PPL:   14.01 | Tokens/Sec: 6074.09
#   Batch 32400/51579   | Avg Loss (last 200): 2.6113 | PPL:   13.62 | Tokens/Sec: 5910.56
#   Batch 32600/51579   | Avg Loss (last 200): 2.6487 | PPL:   14.14 | Tokens/Sec: 6036.88
#   Batch 32800/51579   | Avg Loss (last 200): 2.6537 | PPL:   14.21 | Tokens/Sec: 6023.38
#   Batch 33000/51579   | Avg Loss (last 200): 2.6456 | PPL:   14.09 | Tokens/Sec: 5863.45
#   Batch 33200/51579   | Avg Loss (last 200): 2.6003 | PPL:   13.47 | Tokens/Sec: 6107.04
#   Batch 33400/51579   | Avg Loss (last 200): 2.6441 | PPL:   14.07 | Tokens/Sec: 5977.41
#   Batch 33600/51579   | Avg Loss (last 200): 2.6411 | PPL:   14.03 | Tokens/Sec: 6131.29
#   Batch 33800/51579   | Avg Loss (last 200): 2.6035 | PPL:   13.51 | Tokens/Sec: 5973.00
#   Batch 34000/51579   | Avg Loss (last 200): 2.5991 | PPL:   13.45 | Tokens/Sec: 6111.37
#   Batch 34200/51579   | Avg Loss (last 200): 2.5976 | PPL:   13.43 | Tokens/Sec: 6170.02
#   Batch 34400/51579   | Avg Loss (last 200): 2.6164 | PPL:   13.69 | Tokens/Sec: 6083.28
#   Batch 34600/51579   | Avg Loss (last 200): 2.6435 | PPL:   14.06 | Tokens/Sec: 6213.02
#   Batch 34800/51579   | Avg Loss (last 200): 2.6183 | PPL:   13.71 | Tokens/Sec: 6068.38
#   Batch 35000/51579   | Avg Loss (last 200): 2.6208 | PPL:   13.75 | Tokens/Sec: 6076.04
#   Batch 35200/51579   | Avg Loss (last 200): 2.6186 | PPL:   13.72 | Tokens/Sec: 6097.51
#   Batch 35400/51579   | Avg Loss (last 200): 2.6319 | PPL:   13.90 | Tokens/Sec: 6089.76
#   Batch 35600/51579   | Avg Loss (last 200): 2.5831 | PPL:   13.24 | Tokens/Sec: 5817.47
#   Batch 35800/51579   | Avg Loss (last 200): 2.6097 | PPL:   13.60 | Tokens/Sec: 5682.45
#   Batch 36000/51579   | Avg Loss (last 200): 2.5700 | PPL:   13.07 | Tokens/Sec: 6010.26
#   Batch 36200/51579   | Avg Loss (last 200): 2.6069 | PPL:   13.56 | Tokens/Sec: 6135.74
#   Batch 36400/51579   | Avg Loss (last 200): 2.6422 | PPL:   14.04 | Tokens/Sec: 6143.49
#   Batch 36600/51579   | Avg Loss (last 200): 2.6113 | PPL:   13.62 | Tokens/Sec: 5885.45
#   Batch 36800/51579   | Avg Loss (last 200): 2.6091 | PPL:   13.59 | Tokens/Sec: 5899.71
#   Batch 37000/51579   | Avg Loss (last 200): 2.6219 | PPL:   13.76 | Tokens/Sec: 5944.16
#   Batch 37200/51579   | Avg Loss (last 200): 2.6384 | PPL:   13.99 | Tokens/Sec: 5733.90
#   Batch 37400/51579   | Avg Loss (last 200): 2.6114 | PPL:   13.62 | Tokens/Sec: 5816.15
#   Batch 37600/51579   | Avg Loss (last 200): 2.5985 | PPL:   13.44 | Tokens/Sec: 5871.05
#   Batch 37800/51579   | Avg Loss (last 200): 2.6403 | PPL:   14.02 | Tokens/Sec: 5900.17
#   Batch 38000/51579   | Avg Loss (last 200): 2.6203 | PPL:   13.74 | Tokens/Sec: 5795.09
#   Batch 38200/51579   | Avg Loss (last 200): 2.6087 | PPL:   13.58 | Tokens/Sec: 5729.94
#   Batch 38400/51579   | Avg Loss (last 200): 2.6294 | PPL:   13.87 | Tokens/Sec: 5751.82
#   Batch 38600/51579   | Avg Loss (last 200): 2.6180 | PPL:   13.71 | Tokens/Sec: 5964.05
#   Batch 38800/51579   | Avg Loss (last 200): 2.6306 | PPL:   13.88 | Tokens/Sec: 5773.55
#   Batch 39000/51579   | Avg Loss (last 200): 2.6102 | PPL:   13.60 | Tokens/Sec: 5703.01
#   Batch 39200/51579   | Avg Loss (last 200): 2.6081 | PPL:   13.57 | Tokens/Sec: 6026.08
#   Batch 39400/51579   | Avg Loss (last 200): 2.6166 | PPL:   13.69 | Tokens/Sec: 5755.72
#   Batch 39600/51579   | Avg Loss (last 200): 2.5934 | PPL:   13.38 | Tokens/Sec: 5796.14
#   Batch 39800/51579   | Avg Loss (last 200): 2.6182 | PPL:   13.71 | Tokens/Sec: 5821.79
#   Batch 40000/51579   | Avg Loss (last 200): 2.6033 | PPL:   13.51 | Tokens/Sec: 5943.87
#   Batch 40200/51579   | Avg Loss (last 200): 2.5978 | PPL:   13.43 | Tokens/Sec: 6081.76
#   Batch 40400/51579   | Avg Loss (last 200): 2.5734 | PPL:   13.11 | Tokens/Sec: 5954.61
#   Batch 40600/51579   | Avg Loss (last 200): 2.5840 | PPL:   13.25 | Tokens/Sec: 6002.94
#   Batch 40800/51579   | Avg Loss (last 200): 2.6049 | PPL:   13.53 | Tokens/Sec: 5925.04
#   Batch 41000/51579   | Avg Loss (last 200): 2.6353 | PPL:   13.95 | Tokens/Sec: 5782.41
#   Batch 41200/51579   | Avg Loss (last 200): 2.5966 | PPL:   13.42 | Tokens/Sec: 6051.16
#   Batch 41400/51579   | Avg Loss (last 200): 2.5981 | PPL:   13.44 | Tokens/Sec: 5890.30
#   Batch 41600/51579   | Avg Loss (last 200): 2.6119 | PPL:   13.62 | Tokens/Sec: 5933.22
#   Batch 41800/51579   | Avg Loss (last 200): 2.6287 | PPL:   13.86 | Tokens/Sec: 5983.28
#   Batch 42000/51579   | Avg Loss (last 200): 2.5955 | PPL:   13.40 | Tokens/Sec: 5911.30
#   Batch 42200/51579   | Avg Loss (last 200): 2.5698 | PPL:   13.06 | Tokens/Sec: 6221.90
#   Batch 42400/51579   | Avg Loss (last 200): 2.5919 | PPL:   13.36 | Tokens/Sec: 6085.46
#   Batch 42600/51579   | Avg Loss (last 200): 2.5692 | PPL:   13.06 | Tokens/Sec: 6159.38
#   Batch 42800/51579   | Avg Loss (last 200): 2.5921 | PPL:   13.36 | Tokens/Sec: 5902.64
#   Batch 43000/51579   | Avg Loss (last 200): 2.5920 | PPL:   13.36 | Tokens/Sec: 6028.96
#   Batch 43200/51579   | Avg Loss (last 200): 2.5954 | PPL:   13.40 | Tokens/Sec: 6009.04
#   Batch 43400/51579   | Avg Loss (last 200): 2.6052 | PPL:   13.53 | Tokens/Sec: 5850.61
#   Batch 43600/51579   | Avg Loss (last 200): 2.6018 | PPL:   13.49 | Tokens/Sec: 6107.67
#   Batch 43800/51579   | Avg Loss (last 200): 2.6018 | PPL:   13.49 | Tokens/Sec: 5959.97
#   Batch 44000/51579   | Avg Loss (last 200): 2.5982 | PPL:   13.44 | Tokens/Sec: 6108.23
#   Batch 44200/51579   | Avg Loss (last 200): 2.6052 | PPL:   13.53 | Tokens/Sec: 5888.99
#   Batch 44400/51579   | Avg Loss (last 200): 2.5772 | PPL:   13.16 | Tokens/Sec: 6033.62
#   Batch 44600/51579   | Avg Loss (last 200): 2.5758 | PPL:   13.14 | Tokens/Sec: 5951.58
#   Batch 44800/51579   | Avg Loss (last 200): 2.5980 | PPL:   13.44 | Tokens/Sec: 5989.79
#   Batch 45000/51579   | Avg Loss (last 200): 2.6059 | PPL:   13.54 | Tokens/Sec: 6223.36
#   Batch 45200/51579   | Avg Loss (last 200): 2.5763 | PPL:   13.15 | Tokens/Sec: 5821.39
#   Batch 45400/51579   | Avg Loss (last 200): 2.5980 | PPL:   13.44 | Tokens/Sec: 6011.65
#   Batch 45600/51579   | Avg Loss (last 200): 2.6253 | PPL:   13.81 | Tokens/Sec: 5854.52
#   Batch 45800/51579   | Avg Loss (last 200): 2.6056 | PPL:   13.54 | Tokens/Sec: 5814.20
#   Batch 46000/51579   | Avg Loss (last 200): 2.5482 | PPL:   12.78 | Tokens/Sec: 6160.59
#   Batch 46200/51579   | Avg Loss (last 200): 2.5872 | PPL:   13.29 | Tokens/Sec: 6019.32
#   Batch 46400/51579   | Avg Loss (last 200): 2.5790 | PPL:   13.18 | Tokens/Sec: 6129.94
#   Batch 46600/51579   | Avg Loss (last 200): 2.5676 | PPL:   13.03 | Tokens/Sec: 6005.82
#   Batch 46800/51579   | Avg Loss (last 200): 2.5779 | PPL:   13.17 | Tokens/Sec: 6139.60
#   Batch 47000/51579   | Avg Loss (last 200): 2.6079 | PPL:   13.57 | Tokens/Sec: 5870.51
#   Batch 47200/51579   | Avg Loss (last 200): 2.5934 | PPL:   13.38 | Tokens/Sec: 5949.74
#   Batch 47400/51579   | Avg Loss (last 200): 2.6300 | PPL:   13.87 | Tokens/Sec: 6000.71
#   Batch 47600/51579   | Avg Loss (last 200): 2.5952 | PPL:   13.40 | Tokens/Sec: 5862.80
#   Batch 47800/51579   | Avg Loss (last 200): 2.5971 | PPL:   13.42 | Tokens/Sec: 6127.99
#   Batch 48000/51579   | Avg Loss (last 200): 2.5952 | PPL:   13.40 | Tokens/Sec: 5908.09
#   Batch 48200/51579   | Avg Loss (last 200): 2.6109 | PPL:   13.61 | Tokens/Sec: 5967.17
#   Batch 48400/51579   | Avg Loss (last 200): 2.5997 | PPL:   13.46 | Tokens/Sec: 5946.02
#   Batch 48600/51579   | Avg Loss (last 200): 2.6051 | PPL:   13.53 | Tokens/Sec: 5909.54
#   Batch 48800/51579   | Avg Loss (last 200): 2.5564 | PPL:   12.89 | Tokens/Sec: 5992.46
#   Batch 49000/51579   | Avg Loss (last 200): 2.6112 | PPL:   13.62 | Tokens/Sec: 5836.92
#   Batch 49200/51579   | Avg Loss (last 200): 2.5714 | PPL:   13.08 | Tokens/Sec: 5780.16
#   Batch 49400/51579   | Avg Loss (last 200): 2.5695 | PPL:   13.06 | Tokens/Sec: 6169.96
#   Batch 49600/51579   | Avg Loss (last 200): 2.5944 | PPL:   13.39 | Tokens/Sec: 5955.69
#   Batch 49800/51579   | Avg Loss (last 200): 2.5915 | PPL:   13.35 | Tokens/Sec: 6129.13
#   Batch 50000/51579   | Avg Loss (last 200): 2.5684 | PPL:   13.04 | Tokens/Sec: 5945.90
#   Batch 50200/51579   | Avg Loss (last 200): 2.5656 | PPL:   13.01 | Tokens/Sec: 6086.11
#   Batch 50400/51579   | Avg Loss (last 200): 2.5717 | PPL:   13.09 | Tokens/Sec: 5981.34
#   Batch 50600/51579   | Avg Loss (last 200): 2.5717 | PPL:   13.09 | Tokens/Sec: 6013.82
#   Batch 50800/51579   | Avg Loss (last 200): 2.5780 | PPL:   13.17 | Tokens/Sec: 6071.58
#   Batch 51000/51579   | Avg Loss (last 200): 2.5678 | PPL:   13.04 | Tokens/Sec: 5959.26
#   Batch 51200/51579   | Avg Loss (last 200): 2.5880 | PPL:   13.30 | Tokens/Sec: 6165.46
#   Batch 51400/51579   | Avg Loss (last 200): 2.6069 | PPL:   13.56 | Tokens/Sec: 5988.16
# Validating: 100%|██████████| 17/17 [00:00<00:00, 20.43it/s]
# End of Epoch: 04 | Time: 89m 15s
# 	Epoch Train Loss: 2.646 | Epoch Train PPL:  14.095
# 	Epoch Val. Loss: 3.111 |  Epoch Val. PPL:  22.453
# ----------------------------------------------------------------------
# --- Epoch 05/15 ---
#   Batch   200/51579   | Avg Loss (last 200): 2.5498 | PPL:   12.80 | Tokens/Sec: 5115.45
#   Batch   400/51579   | Avg Loss (last 200): 2.5020 | PPL:   12.21 | Tokens/Sec: 5107.23
#   Batch   600/51579   | Avg Loss (last 200): 2.5346 | PPL:   12.61 | Tokens/Sec: 5844.12
#   Batch   800/51579   | Avg Loss (last 200): 2.5152 | PPL:   12.37 | Tokens/Sec: 5929.46
#   Batch  1000/51579   | Avg Loss (last 200): 2.4929 | PPL:   12.10 | Tokens/Sec: 5787.19
#   Batch  1200/51579   | Avg Loss (last 200): 2.5166 | PPL:   12.39 | Tokens/Sec: 6244.17
#   Batch  1400/51579   | Avg Loss (last 200): 2.5452 | PPL:   12.75 | Tokens/Sec: 5845.97
#   Batch  1600/51579   | Avg Loss (last 200): 2.5071 | PPL:   12.27 | Tokens/Sec: 5674.35
#   Batch  1800/51579   | Avg Loss (last 200): 2.5179 | PPL:   12.40 | Tokens/Sec: 6022.13
#   Batch  2000/51579   | Avg Loss (last 200): 2.5536 | PPL:   12.85 | Tokens/Sec: 5720.36
#   Batch  2200/51579   | Avg Loss (last 200): 2.5317 | PPL:   12.57 | Tokens/Sec: 6237.56
#   Batch  2400/51579   | Avg Loss (last 200): 2.5248 | PPL:   12.49 | Tokens/Sec: 5949.89
#   Batch  2600/51579   | Avg Loss (last 200): 2.5173 | PPL:   12.40 | Tokens/Sec: 5870.38
#   Batch  2800/51579   | Avg Loss (last 200): 2.4930 | PPL:   12.10 | Tokens/Sec: 6078.29
#   Batch  3000/51579   | Avg Loss (last 200): 2.4643 | PPL:   11.76 | Tokens/Sec: 5854.36
#   Batch  3200/51579   | Avg Loss (last 200): 2.4684 | PPL:   11.80 | Tokens/Sec: 6221.40
#   Batch  3400/51579   | Avg Loss (last 200): 2.5075 | PPL:   12.27 | Tokens/Sec: 6041.40
#   Batch  3600/51579   | Avg Loss (last 200): 2.4893 | PPL:   12.05 | Tokens/Sec: 5957.30
#   Batch  3800/51579   | Avg Loss (last 200): 2.5394 | PPL:   12.67 | Tokens/Sec: 5846.55
#   Batch  4000/51579   | Avg Loss (last 200): 2.5191 | PPL:   12.42 | Tokens/Sec: 5928.82
#   Batch  4200/51579   | Avg Loss (last 200): 2.5431 | PPL:   12.72 | Tokens/Sec: 6088.66
#   Batch  4400/51579   | Avg Loss (last 200): 2.5458 | PPL:   12.75 | Tokens/Sec: 5795.54
#   Batch  4600/51579   | Avg Loss (last 200): 2.5137 | PPL:   12.35 | Tokens/Sec: 5990.77
#   Batch  4800/51579   | Avg Loss (last 200): 2.5415 | PPL:   12.70 | Tokens/Sec: 6067.39
#   Batch  5000/51579   | Avg Loss (last 200): 2.4909 | PPL:   12.07 | Tokens/Sec: 5802.45
#   Batch  5200/51579   | Avg Loss (last 200): 2.5053 | PPL:   12.25 | Tokens/Sec: 6083.21
#   Batch  5400/51579   | Avg Loss (last 200): 2.4768 | PPL:   11.90 | Tokens/Sec: 5836.06
#   Batch  5600/51579   | Avg Loss (last 200): 2.5151 | PPL:   12.37 | Tokens/Sec: 6042.70
#   Batch  5800/51579   | Avg Loss (last 200): 2.5048 | PPL:   12.24 | Tokens/Sec: 5820.90
#   Batch  6000/51579   | Avg Loss (last 200): 2.5550 | PPL:   12.87 | Tokens/Sec: 5806.55
#   Batch  6200/51579   | Avg Loss (last 200): 2.5453 | PPL:   12.75 | Tokens/Sec: 6135.30
#   Batch  6400/51579   | Avg Loss (last 200): 2.5129 | PPL:   12.34 | Tokens/Sec: 5876.56
#   Batch  6600/51579   | Avg Loss (last 200): 2.5104 | PPL:   12.31 | Tokens/Sec: 6172.63
#   Batch  6800/51579   | Avg Loss (last 200): 2.5535 | PPL:   12.85 | Tokens/Sec: 5760.85
#   Batch  7000/51579   | Avg Loss (last 200): 2.4909 | PPL:   12.07 | Tokens/Sec: 6092.81
#   Batch  7200/51579   | Avg Loss (last 200): 2.5006 | PPL:   12.19 | Tokens/Sec: 6099.36
#   Batch  7400/51579   | Avg Loss (last 200): 2.4749 | PPL:   11.88 | Tokens/Sec: 6062.14
#   Batch  7600/51579   | Avg Loss (last 200): 2.5214 | PPL:   12.45 | Tokens/Sec: 6098.45
#   Batch  7800/51579   | Avg Loss (last 200): 2.5203 | PPL:   12.43 | Tokens/Sec: 5820.17
#   Batch  8000/51579   | Avg Loss (last 200): 2.5168 | PPL:   12.39 | Tokens/Sec: 6074.17
#   Batch  8200/51579   | Avg Loss (last 200): 2.5108 | PPL:   12.31 | Tokens/Sec: 5946.66
#   Batch  8400/51579   | Avg Loss (last 200): 2.5150 | PPL:   12.37 | Tokens/Sec: 6181.28
#   Batch  8600/51579   | Avg Loss (last 200): 2.5167 | PPL:   12.39 | Tokens/Sec: 6033.27
#   Batch  8800/51579   | Avg Loss (last 200): 2.4928 | PPL:   12.09 | Tokens/Sec: 5975.83
#   Batch  9000/51579   | Avg Loss (last 200): 2.4858 | PPL:   12.01 | Tokens/Sec: 6221.42
#   Batch  9200/51579   | Avg Loss (last 200): 2.4803 | PPL:   11.95 | Tokens/Sec: 5983.80
#   Batch  9400/51579   | Avg Loss (last 200): 2.5237 | PPL:   12.47 | Tokens/Sec: 6211.30
#   Batch  9600/51579   | Avg Loss (last 200): 2.5061 | PPL:   12.26 | Tokens/Sec: 5900.70
#   Batch  9800/51579   | Avg Loss (last 200): 2.4800 | PPL:   11.94 | Tokens/Sec: 6110.29
#   Batch 10000/51579   | Avg Loss (last 200): 2.5060 | PPL:   12.26 | Tokens/Sec: 6037.94
#   Batch 10200/51579   | Avg Loss (last 200): 2.5107 | PPL:   12.31 | Tokens/Sec: 6056.09
#   Batch 10400/51579   | Avg Loss (last 200): 2.4580 | PPL:   11.68 | Tokens/Sec: 6089.80
#   Batch 10600/51579   | Avg Loss (last 200): 2.4923 | PPL:   12.09 | Tokens/Sec: 5948.28
#   Batch 10800/51579   | Avg Loss (last 200): 2.4863 | PPL:   12.02 | Tokens/Sec: 6210.99
#   Batch 11000/51579   | Avg Loss (last 200): 2.4648 | PPL:   11.76 | Tokens/Sec: 6002.82
#   Batch 11200/51579   | Avg Loss (last 200): 2.5506 | PPL:   12.82 | Tokens/Sec: 6046.20
#   Batch 11400/51579   | Avg Loss (last 200): 2.4860 | PPL:   12.01 | Tokens/Sec: 6000.52
#   Batch 11600/51579   | Avg Loss (last 200): 2.5008 | PPL:   12.19 | Tokens/Sec: 5842.86
#   Batch 11800/51579   | Avg Loss (last 200): 2.5032 | PPL:   12.22 | Tokens/Sec: 6067.60
#   Batch 12000/51579   | Avg Loss (last 200): 2.5236 | PPL:   12.47 | Tokens/Sec: 5974.95
#   Batch 12200/51579   | Avg Loss (last 200): 2.5269 | PPL:   12.51 | Tokens/Sec: 6104.62
#   Batch 12400/51579   | Avg Loss (last 200): 2.5014 | PPL:   12.20 | Tokens/Sec: 5936.53
#   Batch 12600/51579   | Avg Loss (last 200): 2.4801 | PPL:   11.94 | Tokens/Sec: 6055.54
#   Batch 12800/51579   | Avg Loss (last 200): 2.4897 | PPL:   12.06 | Tokens/Sec: 6099.76
#   Batch 13000/51579   | Avg Loss (last 200): 2.5220 | PPL:   12.45 | Tokens/Sec: 6026.44
#   Batch 13200/51579   | Avg Loss (last 200): 2.5058 | PPL:   12.25 | Tokens/Sec: 6222.45
#   Batch 13400/51579   | Avg Loss (last 200): 2.5161 | PPL:   12.38 | Tokens/Sec: 5952.58
#   Batch 13600/51579   | Avg Loss (last 200): 2.4669 | PPL:   11.79 | Tokens/Sec: 6158.00
#   Batch 13800/51579   | Avg Loss (last 200): 2.5210 | PPL:   12.44 | Tokens/Sec: 5972.97
#   Batch 14000/51579   | Avg Loss (last 200): 2.5032 | PPL:   12.22 | Tokens/Sec: 6124.33
#   Batch 14200/51579   | Avg Loss (last 200): 2.5054 | PPL:   12.25 | Tokens/Sec: 6141.72
#   Batch 14400/51579   | Avg Loss (last 200): 2.4672 | PPL:   11.79 | Tokens/Sec: 6030.68
#   Batch 14600/51579   | Avg Loss (last 200): 2.5239 | PPL:   12.48 | Tokens/Sec: 6204.20
#   Batch 14800/51579   | Avg Loss (last 200): 2.4973 | PPL:   12.15 | Tokens/Sec: 6005.82
#   Batch 15000/51579   | Avg Loss (last 200): 2.4808 | PPL:   11.95 | Tokens/Sec: 6196.37
#   Batch 15200/51579   | Avg Loss (last 200): 2.5111 | PPL:   12.32 | Tokens/Sec: 6041.16
#   Batch 15400/51579   | Avg Loss (last 200): 2.4767 | PPL:   11.90 | Tokens/Sec: 5918.72
#   Batch 15600/51579   | Avg Loss (last 200): 2.5083 | PPL:   12.28 | Tokens/Sec: 6121.50
#   Batch 15800/51579   | Avg Loss (last 200): 2.4955 | PPL:   12.13 | Tokens/Sec: 5976.37
#   Batch 16000/51579   | Avg Loss (last 200): 2.4920 | PPL:   12.09 | Tokens/Sec: 6054.91
#   Batch 16200/51579   | Avg Loss (last 200): 2.4937 | PPL:   12.11 | Tokens/Sec: 6063.41
#   Batch 16400/51579   | Avg Loss (last 200): 2.4753 | PPL:   11.88 | Tokens/Sec: 6150.41
#   Batch 16600/51579   | Avg Loss (last 200): 2.5005 | PPL:   12.19 | Tokens/Sec: 5902.10
#   Batch 16800/51579   | Avg Loss (last 200): 2.4929 | PPL:   12.10 | Tokens/Sec: 5927.08
#   Batch 17000/51579   | Avg Loss (last 200): 2.5310 | PPL:   12.57 | Tokens/Sec: 6120.19
#   Batch 17200/51579   | Avg Loss (last 200): 2.4962 | PPL:   12.14 | Tokens/Sec: 5988.97
#   Batch 17400/51579   | Avg Loss (last 200): 2.4864 | PPL:   12.02 | Tokens/Sec: 6080.14
#   Batch 17600/51579   | Avg Loss (last 200): 2.4708 | PPL:   11.83 | Tokens/Sec: 5910.20
#   Batch 17800/51579   | Avg Loss (last 200): 2.4939 | PPL:   12.11 | Tokens/Sec: 6054.48
#   Batch 18000/51579   | Avg Loss (last 200): 2.4965 | PPL:   12.14 | Tokens/Sec: 5841.94
#   Batch 18200/51579   | Avg Loss (last 200): 2.5006 | PPL:   12.19 | Tokens/Sec: 5903.38
#   Batch 18400/51579   | Avg Loss (last 200): 2.4989 | PPL:   12.17 | Tokens/Sec: 6053.59
#   Batch 18600/51579   | Avg Loss (last 200): 2.4640 | PPL:   11.75 | Tokens/Sec: 5821.90
#   Batch 18800/51579   | Avg Loss (last 200): 2.5047 | PPL:   12.24 | Tokens/Sec: 6132.18
#   Batch 19000/51579   | Avg Loss (last 200): 2.5140 | PPL:   12.35 | Tokens/Sec: 5848.27
#   Batch 19200/51579   | Avg Loss (last 200): 2.4813 | PPL:   11.96 | Tokens/Sec: 5957.21
#   Batch 19400/51579   | Avg Loss (last 200): 2.4904 | PPL:   12.07 | Tokens/Sec: 6187.21
#   Batch 19600/51579   | Avg Loss (last 200): 2.4959 | PPL:   12.13 | Tokens/Sec: 5915.70
#   Batch 19800/51579   | Avg Loss (last 200): 2.4856 | PPL:   12.01 | Tokens/Sec: 6194.64
#   Batch 20000/51579   | Avg Loss (last 200): 2.4655 | PPL:   11.77 | Tokens/Sec: 5910.47
#   Batch 20200/51579   | Avg Loss (last 200): 2.5111 | PPL:   12.32 | Tokens/Sec: 5770.55
#   Batch 20400/51579   | Avg Loss (last 200): 2.4997 | PPL:   12.18 | Tokens/Sec: 6082.14
#   Batch 20600/51579   | Avg Loss (last 200): 2.4664 | PPL:   11.78 | Tokens/Sec: 5992.86
#   Batch 20800/51579   | Avg Loss (last 200): 2.4811 | PPL:   11.95 | Tokens/Sec: 6273.02
#   Batch 21000/51579   | Avg Loss (last 200): 2.5174 | PPL:   12.40 | Tokens/Sec: 6014.26
#   Batch 21200/51579   | Avg Loss (last 200): 2.4774 | PPL:   11.91 | Tokens/Sec: 6138.79
#   Batch 21400/51579   | Avg Loss (last 200): 2.4836 | PPL:   11.98 | Tokens/Sec: 5904.34
#   Batch 21600/51579   | Avg Loss (last 200): 2.4683 | PPL:   11.80 | Tokens/Sec: 6026.43
#   Batch 21800/51579   | Avg Loss (last 200): 2.4990 | PPL:   12.17 | Tokens/Sec: 6225.98
#   Batch 22000/51579   | Avg Loss (last 200): 2.4932 | PPL:   12.10 | Tokens/Sec: 5887.57
#   Batch 22200/51579   | Avg Loss (last 200): 2.5297 | PPL:   12.55 | Tokens/Sec: 6222.18
#   Batch 22400/51579   | Avg Loss (last 200): 2.5007 | PPL:   12.19 | Tokens/Sec: 5955.27
#   Batch 22600/51579   | Avg Loss (last 200): 2.4960 | PPL:   12.13 | Tokens/Sec: 5945.34
#   Batch 22800/51579   | Avg Loss (last 200): 2.4535 | PPL:   11.63 | Tokens/Sec: 5982.37
#   Batch 23000/51579   | Avg Loss (last 200): 2.5169 | PPL:   12.39 | Tokens/Sec: 6048.35
#   Batch 23200/51579   | Avg Loss (last 200): 2.4801 | PPL:   11.94 | Tokens/Sec: 6133.44
#   Batch 23400/51579   | Avg Loss (last 200): 2.4876 | PPL:   12.03 | Tokens/Sec: 6030.61
#   Batch 23600/51579   | Avg Loss (last 200): 2.5040 | PPL:   12.23 | Tokens/Sec: 6157.33
#   Batch 23800/51579   | Avg Loss (last 200): 2.4548 | PPL:   11.64 | Tokens/Sec: 5893.78
#   Batch 24000/51579   | Avg Loss (last 200): 2.5100 | PPL:   12.30 | Tokens/Sec: 6147.76
#   Batch 24200/51579   | Avg Loss (last 200): 2.4429 | PPL:   11.51 | Tokens/Sec: 6026.86
#   Batch 24400/51579   | Avg Loss (last 200): 2.5114 | PPL:   12.32 | Tokens/Sec: 6119.32
#   Batch 24600/51579   | Avg Loss (last 200): 2.4806 | PPL:   11.95 | Tokens/Sec: 6140.71
#   Batch 24800/51579   | Avg Loss (last 200): 2.4666 | PPL:   11.78 | Tokens/Sec: 6005.97
#   Batch 25000/51579   | Avg Loss (last 200): 2.4569 | PPL:   11.67 | Tokens/Sec: 6181.89
#   Batch 25200/51579   | Avg Loss (last 200): 2.4914 | PPL:   12.08 | Tokens/Sec: 6001.09
#   Batch 25400/51579   | Avg Loss (last 200): 2.4740 | PPL:   11.87 | Tokens/Sec: 6087.58
#   Batch 25600/51579   | Avg Loss (last 200): 2.5297 | PPL:   12.55 | Tokens/Sec: 5986.91
#   Batch 25800/51579   | Avg Loss (last 200): 2.4640 | PPL:   11.75 | Tokens/Sec: 5942.98
#   Batch 26000/51579   | Avg Loss (last 200): 2.4406 | PPL:   11.48 | Tokens/Sec: 6095.14
#   Batch 26200/51579   | Avg Loss (last 200): 2.5009 | PPL:   12.19 | Tokens/Sec: 6017.59
#   Batch 26400/51579   | Avg Loss (last 200): 2.4484 | PPL:   11.57 | Tokens/Sec: 6121.79
#   Batch 26600/51579   | Avg Loss (last 200): 2.4775 | PPL:   11.91 | Tokens/Sec: 5890.80
#   Batch 26800/51579   | Avg Loss (last 200): 2.4805 | PPL:   11.95 | Tokens/Sec: 6261.76
#   Batch 27000/51579   | Avg Loss (last 200): 2.4854 | PPL:   12.01 | Tokens/Sec: 6036.35
#   Batch 27200/51579   | Avg Loss (last 200): 2.4950 | PPL:   12.12 | Tokens/Sec: 6109.86
#   Batch 27400/51579   | Avg Loss (last 200): 2.5159 | PPL:   12.38 | Tokens/Sec: 6027.56
#   Batch 27600/51579   | Avg Loss (last 200): 2.4787 | PPL:   11.93 | Tokens/Sec: 5876.63
#   Batch 27800/51579   | Avg Loss (last 200): 2.5038 | PPL:   12.23 | Tokens/Sec: 5932.40
#   Batch 28000/51579   | Avg Loss (last 200): 2.4664 | PPL:   11.78 | Tokens/Sec: 6085.71
#   Batch 28200/51579   | Avg Loss (last 200): 2.4701 | PPL:   11.82 | Tokens/Sec: 6017.12
#   Batch 28400/51579   | Avg Loss (last 200): 2.4600 | PPL:   11.70 | Tokens/Sec: 5989.68
#   Batch 28600/51579   | Avg Loss (last 200): 2.4926 | PPL:   12.09 | Tokens/Sec: 6030.99
#   Batch 28800/51579   | Avg Loss (last 200): 2.4744 | PPL:   11.87 | Tokens/Sec: 6121.02
#   Batch 29000/51579   | Avg Loss (last 200): 2.4956 | PPL:   12.13 | Tokens/Sec: 6042.15
#   Batch 29200/51579   | Avg Loss (last 200): 2.5057 | PPL:   12.25 | Tokens/Sec: 6017.66
#   Batch 29400/51579   | Avg Loss (last 200): 2.4561 | PPL:   11.66 | Tokens/Sec: 5875.60
#   Batch 29600/51579   | Avg Loss (last 200): 2.5005 | PPL:   12.19 | Tokens/Sec: 5955.63
#   Batch 29800/51579   | Avg Loss (last 200): 2.4460 | PPL:   11.54 | Tokens/Sec: 6060.63
#   Batch 30000/51579   | Avg Loss (last 200): 2.4776 | PPL:   11.91 | Tokens/Sec: 6011.58
#   Batch 30200/51579   | Avg Loss (last 200): 2.4410 | PPL:   11.48 | Tokens/Sec: 6112.52
#   Batch 30400/51579   | Avg Loss (last 200): 2.4627 | PPL:   11.74 | Tokens/Sec: 6161.50
#   Batch 30600/51579   | Avg Loss (last 200): 2.4699 | PPL:   11.82 | Tokens/Sec: 6281.23
#   Batch 30800/51579   | Avg Loss (last 200): 2.5071 | PPL:   12.27 | Tokens/Sec: 6101.05
#   Batch 31000/51579   | Avg Loss (last 200): 2.4638 | PPL:   11.75 | Tokens/Sec: 6255.07
#   Batch 31200/51579   | Avg Loss (last 200): 2.4747 | PPL:   11.88 | Tokens/Sec: 5981.87
#   Batch 31400/51579   | Avg Loss (last 200): 2.4956 | PPL:   12.13 | Tokens/Sec: 6038.56
#   Batch 31600/51579   | Avg Loss (last 200): 2.4641 | PPL:   11.75 | Tokens/Sec: 6129.91
#   Batch 31800/51579   | Avg Loss (last 200): 2.4872 | PPL:   12.03 | Tokens/Sec: 5957.70
#   Batch 32000/51579   | Avg Loss (last 200): 2.4884 | PPL:   12.04 | Tokens/Sec: 6135.23
#   Batch 32200/51579   | Avg Loss (last 200): 2.4594 | PPL:   11.70 | Tokens/Sec: 6068.11
#   Batch 32400/51579   | Avg Loss (last 200): 2.4930 | PPL:   12.10 | Tokens/Sec: 6182.35
#   Batch 32600/51579   | Avg Loss (last 200): 2.5022 | PPL:   12.21 | Tokens/Sec: 5972.46
#   Batch 32800/51579   | Avg Loss (last 200): 2.4728 | PPL:   11.86 | Tokens/Sec: 5996.02
#   Batch 33000/51579   | Avg Loss (last 200): 2.4883 | PPL:   12.04 | Tokens/Sec: 6224.39
#   Batch 33200/51579   | Avg Loss (last 200): 2.4729 | PPL:   11.86 | Tokens/Sec: 6009.27
#   Batch 33400/51579   | Avg Loss (last 200): 2.4552 | PPL:   11.65 | Tokens/Sec: 6136.36
#   Batch 33600/51579   | Avg Loss (last 200): 2.4356 | PPL:   11.42 | Tokens/Sec: 6027.49
#   Batch 33800/51579   | Avg Loss (last 200): 2.4603 | PPL:   11.71 | Tokens/Sec: 6211.91
#   Batch 34000/51579   | Avg Loss (last 200): 2.4767 | PPL:   11.90 | Tokens/Sec: 5964.14
#   Batch 34200/51579   | Avg Loss (last 200): 2.4475 | PPL:   11.56 | Tokens/Sec: 6246.55
#   Batch 34400/51579   | Avg Loss (last 200): 2.4742 | PPL:   11.87 | Tokens/Sec: 6084.95
#   Batch 34600/51579   | Avg Loss (last 200): 2.5071 | PPL:   12.27 | Tokens/Sec: 5956.65
#   Batch 34800/51579   | Avg Loss (last 200): 2.4683 | PPL:   11.80 | Tokens/Sec: 6085.98
#   Batch 35000/51579   | Avg Loss (last 200): 2.4610 | PPL:   11.72 | Tokens/Sec: 6171.90
#   Batch 35200/51579   | Avg Loss (last 200): 2.4711 | PPL:   11.84 | Tokens/Sec: 6150.91
#   Batch 35400/51579   | Avg Loss (last 200): 2.4671 | PPL:   11.79 | Tokens/Sec: 6088.42
#   Batch 35600/51579   | Avg Loss (last 200): 2.4739 | PPL:   11.87 | Tokens/Sec: 6129.16
#   Batch 35800/51579   | Avg Loss (last 200): 2.4446 | PPL:   11.53 | Tokens/Sec: 6098.63
#   Batch 36000/51579   | Avg Loss (last 200): 2.4457 | PPL:   11.54 | Tokens/Sec: 6114.97
#   Batch 36200/51579   | Avg Loss (last 200): 2.4585 | PPL:   11.69 | Tokens/Sec: 6002.11
#   Batch 36400/51579   | Avg Loss (last 200): 2.4425 | PPL:   11.50 | Tokens/Sec: 5958.13
#   Batch 36600/51579   | Avg Loss (last 200): 2.4607 | PPL:   11.71 | Tokens/Sec: 6166.49
#   Batch 36800/51579   | Avg Loss (last 200): 2.4462 | PPL:   11.54 | Tokens/Sec: 5970.71
#   Batch 37000/51579   | Avg Loss (last 200): 2.4922 | PPL:   12.09 | Tokens/Sec: 6155.81
#   Batch 37200/51579   | Avg Loss (last 200): 2.4280 | PPL:   11.34 | Tokens/Sec: 5988.85
#   Batch 37400/51579   | Avg Loss (last 200): 2.4375 | PPL:   11.44 | Tokens/Sec: 6071.98
#   Batch 37600/51579   | Avg Loss (last 200): 2.4583 | PPL:   11.68 | Tokens/Sec: 6102.77
#   Batch 37800/51579   | Avg Loss (last 200): 2.4561 | PPL:   11.66 | Tokens/Sec: 5963.64
#   Batch 38000/51579   | Avg Loss (last 200): 2.4690 | PPL:   11.81 | Tokens/Sec: 6132.11
#   Batch 38200/51579   | Avg Loss (last 200): 2.4694 | PPL:   11.82 | Tokens/Sec: 6039.91
#   Batch 38400/51579   | Avg Loss (last 200): 2.4419 | PPL:   11.49 | Tokens/Sec: 6217.28
#   Batch 38600/51579   | Avg Loss (last 200): 2.4853 | PPL:   12.00 | Tokens/Sec: 5946.68
#   Batch 38800/51579   | Avg Loss (last 200): 2.4634 | PPL:   11.74 | Tokens/Sec: 6246.43
#   Batch 39000/51579   | Avg Loss (last 200): 2.4759 | PPL:   11.89 | Tokens/Sec: 6082.27
#   Batch 39200/51579   | Avg Loss (last 200): 2.4587 | PPL:   11.69 | Tokens/Sec: 6140.05
#   Batch 39400/51579   | Avg Loss (last 200): 2.4159 | PPL:   11.20 | Tokens/Sec: 6164.01
#   Batch 39600/51579   | Avg Loss (last 200): 2.4558 | PPL:   11.66 | Tokens/Sec: 6032.49
#   Batch 39800/51579   | Avg Loss (last 200): 2.4388 | PPL:   11.46 | Tokens/Sec: 6230.85
#   Batch 40000/51579   | Avg Loss (last 200): 2.4584 | PPL:   11.69 | Tokens/Sec: 5965.01
#   Batch 40200/51579   | Avg Loss (last 200): 2.4582 | PPL:   11.68 | Tokens/Sec: 6225.90
#   Batch 40400/51579   | Avg Loss (last 200): 2.4552 | PPL:   11.65 | Tokens/Sec: 6004.43
#   Batch 40600/51579   | Avg Loss (last 200): 2.4469 | PPL:   11.55 | Tokens/Sec: 6183.37
#   Batch 40800/51579   | Avg Loss (last 200): 2.4340 | PPL:   11.40 | Tokens/Sec: 6027.29
#   Batch 41000/51579   | Avg Loss (last 200): 2.4874 | PPL:   12.03 | Tokens/Sec: 6217.04
#   Batch 41200/51579   | Avg Loss (last 200): 2.4380 | PPL:   11.45 | Tokens/Sec: 6117.82
#   Batch 41400/51579   | Avg Loss (last 200): 2.4634 | PPL:   11.75 | Tokens/Sec: 6103.53
#   Batch 41600/51579   | Avg Loss (last 200): 2.4704 | PPL:   11.83 | Tokens/Sec: 6127.81
#   Batch 41800/51579   | Avg Loss (last 200): 2.4638 | PPL:   11.75 | Tokens/Sec: 5949.43
#   Batch 42000/51579   | Avg Loss (last 200): 2.4246 | PPL:   11.30 | Tokens/Sec: 6178.26
#   Batch 42200/51579   | Avg Loss (last 200): 2.4400 | PPL:   11.47 | Tokens/Sec: 6066.99
#   Batch 42400/51579   | Avg Loss (last 200): 2.4550 | PPL:   11.65 | Tokens/Sec: 6215.50
#   Batch 42600/51579   | Avg Loss (last 200): 2.4575 | PPL:   11.68 | Tokens/Sec: 5878.22
#   Batch 42800/51579   | Avg Loss (last 200): 2.4461 | PPL:   11.54 | Tokens/Sec: 6124.03
#   Batch 43000/51579   | Avg Loss (last 200): 2.4185 | PPL:   11.23 | Tokens/Sec: 6052.53
#   Batch 43200/51579   | Avg Loss (last 200): 2.4474 | PPL:   11.56 | Tokens/Sec: 5981.75
#   Batch 43400/51579   | Avg Loss (last 200): 2.4515 | PPL:   11.61 | Tokens/Sec: 6140.49
#   Batch 43600/51579   | Avg Loss (last 200): 2.4538 | PPL:   11.63 | Tokens/Sec: 6001.51
#   Batch 43800/51579   | Avg Loss (last 200): 2.4404 | PPL:   11.48 | Tokens/Sec: 6194.18
#   Batch 44000/51579   | Avg Loss (last 200): 2.4566 | PPL:   11.66 | Tokens/Sec: 5982.83
#   Batch 44200/51579   | Avg Loss (last 200): 2.4626 | PPL:   11.74 | Tokens/Sec: 6201.68
#   Batch 44400/51579   | Avg Loss (last 200): 2.4403 | PPL:   11.48 | Tokens/Sec: 5973.58
#   Batch 44600/51579   | Avg Loss (last 200): 2.4465 | PPL:   11.55 | Tokens/Sec: 5847.33
#   Batch 44800/51579   | Avg Loss (last 200): 2.4250 | PPL:   11.30 | Tokens/Sec: 6048.15
#   Batch 45000/51579   | Avg Loss (last 200): 2.4404 | PPL:   11.48 | Tokens/Sec: 5769.72
#   Batch 45200/51579   | Avg Loss (last 200): 2.4502 | PPL:   11.59 | Tokens/Sec: 6242.75
#   Batch 45400/51579   | Avg Loss (last 200): 2.4406 | PPL:   11.48 | Tokens/Sec: 6034.57
#   Batch 45600/51579   | Avg Loss (last 200): 2.4355 | PPL:   11.42 | Tokens/Sec: 6178.98
#   Batch 45800/51579   | Avg Loss (last 200): 2.4164 | PPL:   11.21 | Tokens/Sec: 5933.89
#   Batch 46000/51579   | Avg Loss (last 200): 2.4643 | PPL:   11.75 | Tokens/Sec: 5913.61
#   Batch 46200/51579   | Avg Loss (last 200): 2.4516 | PPL:   11.61 | Tokens/Sec: 6057.67
#   Batch 46400/51579   | Avg Loss (last 200): 2.4703 | PPL:   11.83 | Tokens/Sec: 5987.98
#   Batch 46600/51579   | Avg Loss (last 200): 2.4381 | PPL:   11.45 | Tokens/Sec: 6245.01
#   Batch 46800/51579   | Avg Loss (last 200): 2.4502 | PPL:   11.59 | Tokens/Sec: 6051.25
#   Batch 47000/51579   | Avg Loss (last 200): 2.4442 | PPL:   11.52 | Tokens/Sec: 6209.28
#   Batch 47200/51579   | Avg Loss (last 200): 2.4253 | PPL:   11.31 | Tokens/Sec: 5895.84
#   Batch 47400/51579   | Avg Loss (last 200): 2.4543 | PPL:   11.64 | Tokens/Sec: 6017.94
#   Batch 47600/51579   | Avg Loss (last 200): 2.4125 | PPL:   11.16 | Tokens/Sec: 6076.16
#   Batch 47800/51579   | Avg Loss (last 200): 2.4376 | PPL:   11.45 | Tokens/Sec: 5959.91
#   Batch 48000/51579   | Avg Loss (last 200): 2.4335 | PPL:   11.40 | Tokens/Sec: 6127.38
#   Batch 48200/51579   | Avg Loss (last 200): 2.4264 | PPL:   11.32 | Tokens/Sec: 5967.68
#   Batch 48400/51579   | Avg Loss (last 200): 2.4447 | PPL:   11.53 | Tokens/Sec: 6328.45
#   Batch 48600/51579   | Avg Loss (last 200): 2.4306 | PPL:   11.37 | Tokens/Sec: 5956.02
#   Batch 48800/51579   | Avg Loss (last 200): 2.4277 | PPL:   11.33 | Tokens/Sec: 6119.36
#   Batch 49000/51579   | Avg Loss (last 200): 2.4556 | PPL:   11.65 | Tokens/Sec: 6141.39
#   Batch 49200/51579   | Avg Loss (last 200): 2.4533 | PPL:   11.63 | Tokens/Sec: 5950.15
#   Batch 49400/51579   | Avg Loss (last 200): 2.3984 | PPL:   11.01 | Tokens/Sec: 6186.85
#   Batch 49600/51579   | Avg Loss (last 200): 2.4423 | PPL:   11.50 | Tokens/Sec: 5981.81
#   Batch 49800/51579   | Avg Loss (last 200): 2.4265 | PPL:   11.32 | Tokens/Sec: 6195.65
#   Batch 50000/51579   | Avg Loss (last 200): 2.4558 | PPL:   11.66 | Tokens/Sec: 6093.89
#   Batch 50200/51579   | Avg Loss (last 200): 2.4456 | PPL:   11.54 | Tokens/Sec: 6097.04
#   Batch 50400/51579   | Avg Loss (last 200): 2.4162 | PPL:   11.20 | Tokens/Sec: 6085.77
#   Batch 50600/51579   | Avg Loss (last 200): 2.4383 | PPL:   11.45 | Tokens/Sec: 5956.75
#   Batch 50800/51579   | Avg Loss (last 200): 2.4144 | PPL:   11.18 | Tokens/Sec: 6137.04
#   Batch 51000/51579   | Avg Loss (last 200): 2.4256 | PPL:   11.31 | Tokens/Sec: 5951.09
#   Batch 51200/51579   | Avg Loss (last 200): 2.4518 | PPL:   11.61 | Tokens/Sec: 6147.78
#   Batch 51400/51579   | Avg Loss (last 200): 2.4429 | PPL:   11.51 | Tokens/Sec: 6016.18
# Validating: 100%|██████████| 17/17 [00:00<00:00, 21.24it/s]
# End of Epoch: 05 | Time: 87m 53s
# 	Epoch Train Loss: 2.479 | Epoch Train PPL:  11.931
# 	Epoch Val. Loss: 2.983 |  Epoch Val. PPL:  19.742
# ----------------------------------------------------------------------
# --- Epoch 06/15 ---
#   Batch   200/51579   | Avg Loss (last 200): 2.3959 | PPL:   10.98 | Tokens/Sec: 5085.74
#   Batch   400/51579   | Avg Loss (last 200): 2.3740 | PPL:   10.74 | Tokens/Sec: 5429.53
#   Batch   600/51579   | Avg Loss (last 200): 2.3996 | PPL:   11.02 | Tokens/Sec: 5842.35
#   Batch   800/51579   | Avg Loss (last 200): 2.3814 | PPL:   10.82 | Tokens/Sec: 6037.19
#   Batch  1000/51579   | Avg Loss (last 200): 2.3541 | PPL:   10.53 | Tokens/Sec: 5998.95
#   Batch  1200/51579   | Avg Loss (last 200): 2.3716 | PPL:   10.71 | Tokens/Sec: 6162.21
#   Batch  1400/51579   | Avg Loss (last 200): 2.3741 | PPL:   10.74 | Tokens/Sec: 6078.93
#   Batch  1600/51579   | Avg Loss (last 200): 2.3533 | PPL:   10.52 | Tokens/Sec: 6218.19
#   Batch  1800/51579   | Avg Loss (last 200): 2.3208 | PPL:   10.18 | Tokens/Sec: 6042.48
#   Batch  2000/51579   | Avg Loss (last 200): 2.3468 | PPL:   10.45 | Tokens/Sec: 6015.39
#   Batch  2200/51579   | Avg Loss (last 200): 2.3829 | PPL:   10.84 | Tokens/Sec: 6037.41
#   Batch  2400/51579   | Avg Loss (last 200): 2.4315 | PPL:   11.38 | Tokens/Sec: 6143.13
#   Batch  2600/51579   | Avg Loss (last 200): 2.3702 | PPL:   10.70 | Tokens/Sec: 6164.79
#   Batch  2800/51579   | Avg Loss (last 200): 2.3662 | PPL:   10.66 | Tokens/Sec: 5915.77
#   Batch  3000/51579   | Avg Loss (last 200): 2.3881 | PPL:   10.89 | Tokens/Sec: 6174.08
#   Batch  3200/51579   | Avg Loss (last 200): 2.3492 | PPL:   10.48 | Tokens/Sec: 5920.20
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-39-1369913679.py in <cell line: 0>()
#       2     print(f"--- Epoch {epoch+1:02d}/{config['epochs']:02d} ---")
#       3
# ----> 4     train_loss, train_duration = train_epoch(
#       5         model, train_dataloader, optimizer, criterion, device, config, epoch + 1
#       6     )
#
# /tmp/ipython-input-26-392631358.py in train_epoch(model, dataloader, optimizer, criterion, device, config, epoch_num)
#      31             loss = loss / config['accumulation_steps']
#      32
# ---> 33         scaler.scale(loss).backward()
#      34
#      35         if (i + 1) % config['accumulation_steps'] == 0:
#
# /usr/local/lib/python3.11/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     624                 inputs=inputs,
#     625             )
# --> 626         torch.autograd.backward(
#     627             self, gradient, retain_graph, create_graph, inputs=inputs
#     628         )
#
# /usr/local/lib/python3.11/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     345     # some Python versions print out the first line of a multi-line function
#     346     # calls in the traceback and some print out the last line
# --> 347     _engine_run_backward(
#     348         tensors,
#     349         grad_tensors_,
#
# /usr/local/lib/python3.11/dist-packages/torch/autograd/graph.py in _engine_run_backward(t_outputs, *args, **kwargs)
#     821         unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     822     try:
# --> 823         return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     824             t_outputs, *args, **kwargs
#     825         )  # Calls into the C++ engine to run the backward pass
#
# KeyboardInterrupt:
